# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {}

# %%
data["numSearchTerms"] = [1,2,3,4,5,10]

# %%
data["MeanResponses_Standard"] = [517.8,311.75,72.3,13,7,1]

# %%
data["MeanResponses_Fuzzy"] = [517.8,311.75,72.3,13, 7, 1]

# %%
data["MeanResponses_Ranked"] = [517.8,311.75,72.3,13, 7, 1]

# %%
data["MeanResponses_Pictorial_LO"] = [339,460,551,684,692,774]

# %%
data["MeanResponses_Pictorial_OO"] = [1070,392,30,9,2,0]

# %%
data["Mean_time_standard"] = [0.000021505355835,0.000023245811462,0.000032333333334,0.000052999999999,0.000035,0.00004]

# %%
data["Mean_time_Fuzzy"] = [0.1507526,0.183480867267609,0.063791,0.015404500000001,0.010492086410522461,0.000030994415283]

# %%
data["Mean_time_Ranked"] = [0.149085283279419,0.180780529975891,0.063608725865682,0.01571527862549,0.01014399528503418,0.002930164337158203]

# %%
data["Mean_time_pictorial_LO"] = [0.0004820823669433594,0.0005671977996826172,0.0008389949798583984,0.0008981227874755859,0.0009779930114746094,0.0013020038604736328]

# %%
data["Mean_time_pictorial_OO"] = [0.02671194076538086,0.12195086479187012,0.14454102516174316,0.14905595779418945,0.14871764183044434,0.15140867233276367 ]

# %%
data
# Out:
# {'numSearchTerms': [1, 2, 3, 4, 5, 10],
#  'MeanResponses_Standard': [517.8, 311.75, 72.3, 13, 7, 1],
#  'MeanResponses_Fuzzy': [517.8, 311.75, 72.3, 13, 7, 1],
#  'MeanResponses_Ranked': [517.8, 311.75, 72.3, 13, 7, 1],
#  'MeanResponses_Pictorial_LO': [339, 460, 551, 684, 692, 774],
#  'MeanResponses_Pictorial_OO': [1070, 392, 30, 9, 2, 0],
#  'Mean_time_standard': [2.1505355835e-05,
#   2.3245811462e-05,
#   3.2333333334e-05,
#   5.2999999999e-05,
#   3.5e-05,
#   4e-05],
#  'Mean_time_Fuzzy': [0.1507526,
#   0.183480867267609,
#   0.063791,
#   0.015404500000001,
#   0.010492086410522461,
#   3.0994415283e-05],
#  'Mean_time_Ranked': [0.149085283279419,
#   0.180780529975891,
#   0.063608725865682,
#   0.01571527862549,
#   0.01014399528503418,
#   0.002930164337158203],
#  'Mean_time_pictorial_LO': [0.0004820823669433594,
#   0.0005671977996826172,
#   0.0008389949798583984,
#   0.0008981227874755859,
#   0.0009779930114746094,
#   0.0013020038604736328],
#  'Mean_time_pictorial_OO': [0.02671194076538086,
#   0.12195086479187012,
#   0.14454102516174316,
#   0.14905595779418945,
#   0.14871764183044434,
#   0.15140867233276367]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    numSearchTerms  MeanResponses_Standard  MeanResponses_Fuzzy  \
# 0               1                  517.80               517.80
# 1               2                  311.75               311.75
# 2               3                   72.30                72.30
# 3               4                   13.00                13.00
# 4               5                    7.00                 7.00
# 5              10                    1.00                 1.00
#
#    MeanResponses_Ranked  MeanResponses_Pictorial_LO  \
# 0                517.80                         339
# 1                311.75                         460
# 2                 72.30                         551
# 3                 13.00                         684
# 4                  7.00                         692
# 5                  1.00                         774
#
#    MeanResponses_Pictorial_OO  Mean_time_standard  Mean_time_Fuzzy  \
# 0                        1070            0.000022         0.150753
# 1                         392            0.000023         0.183481
# 2                          30            0.000032         0.063791
# 3                           9            0.000053         0.015405
# 4                           2            0.000035         0.010492
# 5                           0            0.000040         0.000031
#
#    Mean_time_Ranked  Mean_time_pictorial_LO  Mean_time_pictorial_OO
# 0          0.149085                0.000482                0.026712
# 1          0.180781                0.000567                0.121951
# 2          0.063609                0.000839                0.144541
# 3          0.015715                0.000898                0.149056
# 4          0.010144                0.000978                0.148718
# 5          0.002930                0.001302                0.151409

# %%
plt.plot(df.numSearchTerms,df.MeanResponses_Standard	, label = "Standard Query")
plt.plot(df.numSearchTerms,df.MeanResponses_Fuzzy	, label = "Fuzzy Query")
plt.plot(df.numSearchTerms,df.MeanResponses_Ranked	, label = "Ranked Query")
plt.plot(df.numSearchTerms,df.MeanResponses_Pictorial_LO	, label = "Pictorial LO Query")
plt.plot(df.numSearchTerms,df.MeanResponses_Pictorial_OO	, label = "Pictorial OO Query")

plt.title("Query Modes versus recall of query")
plt.xlabel("Number of Query Terms")
plt.ylabel("Mean Number of Candiate Locations")

plt.legend()
plt.show()

# %%
plt.plot(df.numSearchTerms,df.Mean_time_standard	, label = "Standard Query")
plt.plot(df.numSearchTerms,df.Mean_time_Fuzzy	, label = "Fuzzy Query")
plt.plot(df.numSearchTerms,df.Mean_time_Ranked	, label = "Ranked Query")
plt.plot(df.numSearchTerms,df.Mean_time_pictorial_LO	, label = "Pictorial LO Query")
plt.plot(df.numSearchTerms,df.Mean_time_pictorial_OO	, label = "Pictorial OO Query")

plt.title("Query Modes versus execution wall time")
plt.xlabel("Number of Query Terms")
plt.ylabel("Mean Time taken to execute query (seconds)")

plt.legend()
plt.show()
