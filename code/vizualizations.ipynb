# %%
pip install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, os
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
cwd = "/Users/kentosullivan/Desktop/CMSC828T-Project/code"
os.chdir(cwd)
print(cwd)

os.chdir("..")
os.chdir("data")
dataDir = os.getcwd()
print(dataDir)

os.chdir(cwd)
print(os.getcwd())
# Out:
# /Users/kentosullivan/Desktop/CMSC828T-Project/code
# /Users/kentosullivan/Desktop/CMSC828T-Project/data
# /Users/kentosullivan/Desktop/CMSC828T-Project/code

# %%
osm_df = pd.read_csv(dataDir+'/osm_df.csv')
osm_df
# Out:
#                             location    latitude  longitude
# 0                  Sandalford Winery  115.992759 -31.868701
# 1                      Nikola Estate  115.997995 -31.854112
# 2                 Edgecombe Brothers  115.998571 -31.795187
# 3       Little River Winery and Café  116.000888 -31.824124
# 4   Black Swan Winery and Restaurant  116.000850 -31.823404
# 5                    Lancaster Wines  115.988887 -31.852260
# 6                     Mandoon Estate  115.994991 -31.868266
# 7                   Mandoon Vineyard  115.995494 -31.867594
# 8                    Oakover Grounds  116.007327 -31.845080
# 9                 Henley Park Winery  116.001641 -31.797776
# 10                Upper Reach Winery  116.008634 -31.795033
# 11                       Mann Winery  116.012546 -31.793688
# 12  Harris Organic Wines and Spirits  116.020830 -31.794595
# 13               John Kosovich Wines  116.020760 -31.795346
# 14                   Twin Hill Wines  116.020781 -31.796729
# ...

# %%
obj_df = pd.read_csv(dataDir+'/obj_df.csv')
obj_df
# Out:
#            object    latitude  longitude    true_location  cluster  \
# 0       palm_tree  116.018337 -31.814452    Alis_Vineyard        0
# 1       palm_tree  116.018326 -31.814519    Alis_Vineyard        0
# 2       palm_tree  116.018316 -31.814572    Alis_Vineyard        0
# 3       palm_tree  116.018253 -31.814581    Alis_Vineyard        0
# 4       palm_tree  116.018209 -31.814622    Alis_Vineyard        0
# ..            ...         ...        ...              ...      ...
# 141  picnic_table  115.990902 -31.851874  Lancaster_Wines        5
# 142  picnic_table  115.990921 -31.851803  Lancaster_Wines        5
# 143  picnic_table  115.990867 -31.851802  Lancaster_Wines        5
# 144  picnic_table  115.990801 -31.851801  Lancaster_Wines        5
# 145  picnic_table  115.990753 -31.851802  Lancaster_Wines        5
#
#     PredictedLocation
# 0      Ali's Vineyard
# 1      Ali's Vineyard
# 2      Ali's Vineyard
# 3      Ali's Vineyard
# 4      Ali's Vineyard
# ...

# %%
plot = osm_df.plot.scatter(x='latitude', y='longitude', c='DarkBlue')

# %%
plot = obj_df.plot.scatter(x='latitude', y='longitude', c='Red')

# %%
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.scatter(obj_df['latitude'],obj_df['longitude'], label="Objects")
plt.scatter(osm_df['latitude'],osm_df['longitude'], label="Locations")

# %%
#colors = ['Red', 'Pink', 'Yellow', 'Blue', 'Green', 'Indigo']
#obj_df['c'] = obj_df.cluster.map({0:colors[0], 1:colors[1], 2:colors[2], 3:colors[3], 
#                          4:colors[4], 5:colors[5]})
plt.scatter(obj_df.latitude ,obj_df.longitude, c=obj_df.cluster, alpha =0.6, s=10)
plt.scatter(osm_df['latitude'],osm_df['longitude'], label="Locations",alpha =0.6, s=10 )
